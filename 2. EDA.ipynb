# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
nv = pd.read_csv('filted_nv.csv')

# %%
nv
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x               review_id  \
# 0                38        852432       1428821  dokQIMcveyRcoqaTghiUMA
# 1                72       5005872       5165282  pN4hqX_6Bb8nxu_9U720cw
# 2                78       5750928       5862280  uyrnduQmgFHRMt_8lOIMCQ
# 3               121       3692900       3977478  5-qw7FK5y4qB6fRZbRodHw
# 4               482       1075682       1334815  EEzO2FQAl6V15j6ITXWilA
# ...             ...           ...           ...                     ...
# 1410249     4223170       8020159       7886379  tEXwLl3dlIsMbo9YcbyAdQ
# 1410250     4223171       8020180       7918513  LKh2HsjBkZG_q3zDHvxE4A
# 1410251     4223172       8020182       7975721  eqkqSkKCKtcgfDOP_M8OVg
# 1410252     4223173       8020183       8001469  38NzCbjBvhdV4QxrpA-gwg
# 1410253     4223179       8020405       7980235  ePXwx5sSke62nAYNRAuzcw
#
#                         user_id             business_id  stars_r  useful_r  \
# ...

# %%
nv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1410254 entries, 0 to 1410253
# Data columns (total 47 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Unnamed: 0          1410254 non-null  int64
#  1   Unnamed: 0.1        1410254 non-null  int64
#  2   Unnamed: 0_x        1410254 non-null  int64
#  3   review_id           1410254 non-null  object
#  4   user_id             1410254 non-null  object
#  5   business_id         1410254 non-null  object
#  6   stars_r             1410254 non-null  int64
#  7   useful_r            1410254 non-null  int64
#  8   funny_r             1410254 non-null  int64
#  9   cool_r              1410254 non-null  float64
#  10  text                1410253 non-null  object
#  11  date                1410254 non-null  object
#  12  Unnamed: 0_y        1410254 non-null  float64
#  13  name_b              1410254 non-null  object
#  14  address             1407485 non-null  object
# ...

# %%
nv[['useful_r', 'funny_r', 'cool_r', 'useful_u', 'funny_u', 'cool_u']]
# Out:
#          useful_r  funny_r  cool_r  useful_u  funny_u  cool_u
# 0               1        1     1.0       698      331     312
# 1               2        2     0.0       698      331     312
# 2               2        1     1.0       698      331     312
# 3               1        2     0.0        95       51      20
# 4               0        0     0.0       127       48      85
# ...           ...      ...     ...       ...      ...     ...
# 1410249         1        0     0.0         1        0       0
# 1410250         0        1     0.0         2        1       1
# 1410251         0        1     0.0         0        1       0
# 1410252         0        1     0.0        17        3       9
# 1410253         0        0     0.0         0        0       0
#
# [1410254 rows x 6 columns]

# %%
# Initialize the word cloud
wc = WordCloud(width = 500, height = 500, min_font_size = 10, background_color ='white')


cate = nv['text'].str.cat(sep=' ')
cate_wc = wc.generate(cate)
    
# plot
plt.figure(figsize = (5, 5), facecolor = None) 
plt.imshow(cate_wc) 
plt.axis("off") 
plt.title("Common words in category")
plt.tight_layout(pad = 0) 
plt.show()

# %%
wc1 = WordCloud(width = 500, height = 500, min_font_size = 10, background_color ='white')

for i in range(2):
    cate = df_text[df_text['quality'] == i]['text'].str.cat(sep=' ')
    cate_wc = wc.generate(cate)
    
    # plot
    plt.figure(figsize = (5, 5), facecolor = None) 
    plt.imshow(cate_wc) 
    plt.axis("off") 
    plt.title("Common words in category {}".format(i))
    plt.tight_layout(pad = 0) 
    plt.show()

# %%
# Initialize the word cloud
wc = WordCloud(width = 500, height = 500, min_font_size = 10, background_color ='white')


cate = nv['text'].str.cat(sep=' ')
cate_wc = wc.generate(cate)
    
# plot
plt.figure(figsize = (5, 5), facecolor = None) 
plt.imshow(cate_wc) 
plt.axis("off") 
plt.title("Common words in category")
plt.tight_layout(pad = 0) 
plt.show()

# %%
import seaborn as sns 

#Get the distribution of the ratings
x=nv['stars_r'].value_counts()
x=x.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("Star Rating Distribution of Reviews")
plt.ylabel('# of businesses', fontsize=12)
plt.xlabel('Star Ratings ', fontsize=12)

#adding the text labels
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
#Get the distribution of the ratings
x=nv['stars_b'].value_counts()
x=x.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("Star Rating Distribution of Businesses")
plt.ylabel('# of businesses', fontsize=12)
plt.xlabel('Star Ratings ', fontsize=12)

#adding the text labels
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
### For Linux's Users
# import os
# os.environ['PROJ_LIB'] = r'/home/XXXXXX/anaconda3/pkgs/proj4-5.2.0- he6710b0_1/share/proj'
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib
from mpl_toolkits.basemap import Basemap


lon_min, lon_max = -115.40710729999999, -114.83545
lat_min, lat_max = 35.9208835,36.381974

#create the selector
idx_NA = (nv["longitude"]>lon_min) &\
            (nv["longitude"]<lon_max) &\
            (nv["latitude"]>lat_min) &\
            (nv["latitude"]<lat_max)
#apply the selector to subset
NV_business=nv[idx_NA]

#initiate the figure
plt.figure(figsize=(12,6))
m2 = Basemap(projection='merc',
             llcrnrlat=lat_min,
             urcrnrlat=lat_max,
             llcrnrlon=lon_min,
             urcrnrlon=lon_max,
             lat_ts=35,
             resolution='i')

m2.fillcontinents(color='#191919',lake_color='#000000') # dark grey land, black lakes
m2.drawmapboundary(fill_color='#000000')                # black background
m2.drawcountries(linewidth=0.1, color="w")              # thin white line for country borders

# Plot the data
mxy = m2(NV_business["longitude"].tolist(), NV_business["latitude"].tolist())
m2.scatter(mxy[0], mxy[1], s=5, c="yellow", lw=0, alpha=0.05, zorder=5)

plt.title("Nevada Region")
# Out:
# Text(0.5, 1.0, 'Nevada Region')

# %%
nv['longitude'].min()
# Out:
# -115.40710729999999

# %%
nv['longitude'].max()
# Out:
# -114.83545

# %%
nv['latitude'].min()
# Out:
# 35.9208835

# %%
nv['latitude'].max()
# Out:
# 36.381974

# %%
user_agg=nv.groupby('business_id').agg({'review_count_b':['mean'],'date':['min','max'],
                                'useful_r':['sum'],'funny_r':['sum'],'cool_r':['sum'],
                               'stars_b':['mean']})

# %%
user_agg=user_agg.sort_values([('review_count_b','mean')],ascending=False)
print("          Top 10 Restaurants in Yelp")
user_agg.head(10)
# Out:
#           Top 10 Restaurants in Yelp
#                        review_count_b                 date  \
#                                  mean                  min
# business_id
# RESDUcs7fIiihp38-d6_6g        10129.0  2012-09-10 20:03:19
# 4JNXUYY8wbaaDmk3BPzlWw         9264.0  2005-10-10 20:01:53
# K7lWdNUhCbcnEvI0NhGewg         7383.0  2010-12-18 03:07:06
# f4x1YBxkLrZg652xt2KR5g         6751.0  2010-01-29 19:51:52
# DkYS3arLOhA8si5uUEmHOw         5232.0  2007-10-08 17:10:31
# faPVqws-x-5k2CQKDNtHxw         4828.0  2014-12-29 04:13:26
# 2weQS-RnoOBhb1KsHKyoSQ         4803.0  2006-04-11 07:58:43
# iCQpiavjjPzJ5_3gPD5Ebg         4803.0  2010-12-20 08:31:37
# 5LNZ67Yw9RD6nf4_UhXOjw         4740.0  2010-11-21 23:05:30
# vHz2RLtfUMVRPFmd7VBEHA         4672.0  2018-01-05 06:27:56
#
#                                             useful_r funny_r  cool_r stars_b
#                                         max      sum     sum     sum    mean
# business_id
# ...

# %%
nv[nv['business_id']=='RESDUcs7fIiihp38-d6_6g'][['date','review_count_b']]
# Out:
#                         date  review_count_b
# 16       2013-05-12 03:31:19         10129.0
# 31       2017-02-23 00:15:41         10129.0
# 69       2019-04-12 05:22:45         10129.0
# 87       2014-07-29 23:11:36         10129.0
# 204      2013-06-28 16:42:42         10129.0
# ...                      ...             ...
# 1026403  2019-12-05 18:01:49         10129.0
# 1026405  2019-12-05 21:34:56         10129.0
# 1026406  2019-11-17 20:39:36         10129.0
# 1026407  2019-11-12 02:23:07         10129.0
# 1026408  2019-12-12 03:27:22         10129.0
#
# [10417 rows x 2 columns]

# %%
nv[nv['user_id']=='zFCuveEe6M-ijY1iy23IJg'][['useful_r', 'funny_r', 'cool_r', 'useful_u', 'funny_u', 'cool_u']]

# %%
nv[['useful_r', 'funny_r', 'cool_r']].describe()
# Out:
#            useful_r       funny_r        cool_r
# count  1.410254e+06  1.410254e+06  1.410254e+06
# mean   1.097151e+00  4.909697e-01  6.604895e-01
# std    3.553186e+00  2.320714e+00  2.982014e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00
# 75%    1.000000e+00  0.000000e+00  0.000000e+00
# max    7.580000e+02  7.860000e+02  3.210000e+02

# %%
nv['vote_r'] = nv['useful_r'] + nv['funny_r'] + nv['cool_r']

# %%
user_vote=nv.groupby('user_id').agg({'review_id':['count'],'date':['min','max'],
                                'vote_r':['mean'],
                               'stars_r':['mean']})
user_vote=user_vote.sort_values([('vote_r','mean')],ascending=False)
user_vote.head()
# Out:
#                        review_id                 date                       \
#                            count                  min                  max
# user_id
# kGbRvQ1iEQus_kJ_54RtZA         1  2019-02-12 03:14:20  2019-02-12 03:14:20
# ax7SnXOTIpatbsmqHLqVow         2  2015-12-12 14:28:26  2016-01-03 14:41:09
# TJ57yRrjTlEC8wcyvvCoeQ         3  2018-03-07 17:30:22  2018-03-13 09:21:05
# b6RPXYOsxARZlZh52Y1isA         1  2016-08-22 21:14:41  2016-08-22 21:14:41
# K74S1UK7QjAhWnkXIN0nhg         6  2019-01-23 23:32:07  2019-02-01 21:43:01
#
#                              vote_r   stars_r
#                                mean      mean
# user_id
# kGbRvQ1iEQus_kJ_54RtZA  1865.000000  1.000000
# ax7SnXOTIpatbsmqHLqVow   480.500000  3.000000
# TJ57yRrjTlEC8wcyvvCoeQ   450.666667  4.000000
# b6RPXYOsxARZlZh52Y1isA   448.000000  1.000000
# K74S1UK7QjAhWnkXIN0nhg   444.333333  4.666667

# %%
start_time=time.time()

# Cap max reviews to 30 for better visuals
user_vote[('vote_r','mean')].loc[user_vote[('vote_r','mean')]>30] = 30
plt.figure(figsize=(12,5))
plt.suptitle("Review Deep dive",fontsize=20)
gridspec.GridSpec(1,2)
plt.subplot2grid((1,2),(0,0))
#Cumulative Distribution
ax=sns.kdeplot(user_vote[('vote_r','mean')],shade=True,color='r')
plt.title("How many votes does a review receive in average?",fontsize=15)
plt.xlabel('# of votes given', fontsize=12)
plt.ylabel('Density of votes', fontsize=12)

#Cumulative Distribution
plt.subplot2grid((1,2),(0,1))
sns.distplot(user_vote[('vote_r','mean')],
             kde_kws=dict(cumulative=True))
plt.title("Cumulative dist. of votes",fontsize=15)
plt.ylabel('Cumulative perc. of votes', fontsize=12)
plt.xlabel('# of votes given', fontsize=12)

plt.show()
end_time=time.time()
print("Took",end_time-start_time,"s")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# Took 14.439056873321533 s
